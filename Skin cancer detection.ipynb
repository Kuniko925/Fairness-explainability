# %%
import numpy as np
import pandas as pd
import os
import math
from glob import glob

import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adamax
from keras.utils import plot_model

import sklearn.metrics
from sklearn.metrics import confusion_matrix, f1_score, classification_report
from sklearn.linear_model import LinearRegression

import shutil
from tqdm import tqdm
import albumentations as A
# Out:
# WARNING:tensorflow:From C:\hampython\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
root_path = "d:/ham/"
original_test_df_path = root_path + "ham_test_dataframe/df_test_original.csv"
original_test_df = pd.read_csv(original_test_df_path)
original_test_df["labels"] = original_test_df["labels"].astype(str) #y_col="labels" column values must be type string, list or tuple

test_df_path = root_path + "ham_test_dataframe/df_test_ita.csv"
test_df = pd.read_csv(test_df_path)
test_df["labels"] = test_df["labels"].astype(str)

model_path = "d:/ham/ham_work_folder/saved_model/"

# %%
img_size = (310,640)
batch_size=16
ycol='labels'

trgen=ImageDataGenerator(horizontal_flip=True)
t_and_v_gen=ImageDataGenerator()

def make_generator(df, xcol):
    length=len(df)
    test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]
    test_steps=int(length/test_batch_size)
    test_gen=t_and_v_gen.flow_from_dataframe(df, x_col=xcol, y_col=ycol, target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=test_batch_size)
    return test_gen

# Image data generator
original_test_gen = make_generator(original_test_df, "filepaths")
test_gen = make_generator(test_df, "filepaths")
# Out:
# Found 259 validated image filenames belonging to 7 classes.
# Found 25900 validated image filenames belonging to 7 classes.

# %%
def F1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
def print_in_color(txt_msg,fore_tupple=(0,255,255),back_tupple=(100,100,100)):
    #prints the text_msg in the foreground color specified by fore_tupple with the background specified by back_tupple
    #text_msg is the text, fore_tupple is foregroud color tupple (r,g,b), back_tupple is background tupple (r,g,b)
    # default parameter print in cyan foreground and gray background
    rf,gf,bf=fore_tupple
    rb,gb,bb=back_tupple
    msg='{0}' + txt_msg
    mat='\33[38;2;' + str(rf) +';' + str(gf) + ';' + str(bf) + ';48;2;' + str(rb) + ';' +str(gb) + ';' + str(bb) +'m'
    print(msg .format(mat), flush=True)
    print('\33[0m', flush=True) # returns default print color to back to black
    return

# %% [markdown]
# ## Load trained model

# %%
# load trained model
model = tf.keras.models.load_model(model_path, custom_objects={'F1_score': F1_score})

# Needs to compile again as for lr setting
lr=.001
model.compile(Adamax(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy', F1_score, 'AUC'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 310, 640, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 310, 640, 3)          0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, 310, 640, 3)          7         ['rescaling[0][0]']
#  on)
#
#  rescaling_1 (Rescaling)     (None, 310, 640, 3)          0         ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 311, 641, 3)          0         ['rescaling_1[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 155, 320, 40)         1080      ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 155, 320, 40)         160       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 155, 320, 40)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 155, 320, 40)         360       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 155, 320, 40)         160       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 155, 320, 40)         0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 40)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 40)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 10)             410       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 40)             440       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 155, 320, 40)         0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 155, 320, 24)         960       ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 155, 320, 24)         96        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 155, 320, 24)         216       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 155, 320, 24)         96        ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 155, 320, 24)         0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 24)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 24)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 6)              150       ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 24)             168       ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 155, 320, 24)         0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 155, 320, 24)         576       ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 155, 320, 24)         96        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (Dropout)      (None, 155, 320, 24)         0         ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)           (None, 155, 320, 24)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 155, 320, 144)        3456      ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 155, 320, 144)        576       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 155, 320, 144)        0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 157, 321, 144)        0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 78, 160, 144)         1296      ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 78, 160, 144)         576       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 78, 160, 144)         0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 144)                  0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 78, 160, 144)         0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 78, 160, 32)          4608      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 78, 160, 32)          128       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 78, 160, 192)         6144      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 78, 160, 192)         768       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 78, 160, 192)         0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 78, 160, 192)         1728      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 78, 160, 192)         768       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 78, 160, 192)         0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 192)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 78, 160, 192)         0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 78, 160, 32)          6144      ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 78, 160, 32)          128       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 78, 160, 32)          0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 78, 160, 32)          0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 78, 160, 192)         6144      ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 78, 160, 192)         768       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 78, 160, 192)         0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 78, 160, 192)         1728      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 78, 160, 192)         768       ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 78, 160, 192)         0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 192)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 78, 160, 192)         0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 78, 160, 32)          6144      ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 78, 160, 32)          128       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 78, 160, 32)          0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 78, 160, 32)          0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 78, 160, 192)         6144      ['block2c_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 78, 160, 192)         768       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 78, 160, 192)         0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 81, 163, 192)         0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 39, 80, 192)          4800      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 39, 80, 192)          768       ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 39, 80, 192)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 192)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 39, 80, 192)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 39, 80, 48)           9216      ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 39, 80, 48)           192       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 39, 80, 288)          13824     ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 39, 80, 288)          1152      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 39, 80, 288)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_dwconv (DepthwiseC  (None, 39, 80, 288)          7200      ['block3b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3b_bn (BatchNormaliza  (None, 39, 80, 288)          1152      ['block3b_dwconv[0][0]']
#  tion)
#
#  block3b_activation (Activa  (None, 39, 80, 288)          0         ['block3b_bn[0][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 288)                  0         ['block3b_activation[0][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3b_se_squeeze[0][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multipl  (None, 39, 80, 288)          0         ['block3b_activation[0][0]',
#  y)                                                                  'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv  (None, 39, 80, 48)           13824     ['block3b_se_excite[0][0]']
#  2D)
#
#  block3b_project_bn (BatchN  (None, 39, 80, 48)           192       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 39, 80, 48)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 39, 80, 48)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 39, 80, 288)          13824     ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 39, 80, 288)          1152      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 39, 80, 288)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_dwconv (DepthwiseC  (None, 39, 80, 288)          7200      ['block3c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3c_bn (BatchNormaliza  (None, 39, 80, 288)          1152      ['block3c_dwconv[0][0]']
#  tion)
#
#  block3c_activation (Activa  (None, 39, 80, 288)          0         ['block3c_bn[0][0]']
#  tion)
#
#  block3c_se_squeeze (Global  (None, 288)                  0         ['block3c_activation[0][0]']
#  AveragePooling2D)
#
#  block3c_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3c_se_squeeze[0][0]']
#  e)
#
#  block3c_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multipl  (None, 39, 80, 288)          0         ['block3c_activation[0][0]',
#  y)                                                                  'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv  (None, 39, 80, 48)           13824     ['block3c_se_excite[0][0]']
#  2D)
#
#  block3c_project_bn (BatchN  (None, 39, 80, 48)           192       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 39, 80, 48)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 39, 80, 48)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 39, 80, 288)          13824     ['block3c_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 39, 80, 288)          1152      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 39, 80, 288)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv_pad (ZeroPa  (None, 41, 81, 288)          0         ['block4a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block4a_dwconv (DepthwiseC  (None, 20, 40, 288)          2592      ['block4a_dwconv_pad[0][0]']
#  onv2D)
#
#  block4a_bn (BatchNormaliza  (None, 20, 40, 288)          1152      ['block4a_dwconv[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 20, 40, 288)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 288)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 20, 40, 288)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 20, 40, 96)           27648     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 20, 40, 96)           384       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 20, 40, 576)          55296     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 20, 40, 576)          2304      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 20, 40, 576)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv (DepthwiseC  (None, 20, 40, 576)          5184      ['block4b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4b_bn (BatchNormaliza  (None, 20, 40, 576)          2304      ['block4b_dwconv[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 20, 40, 576)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 576)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 576)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 24)             13848     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 576)            14400     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 20, 40, 576)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 20, 40, 96)           55296     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 20, 40, 96)           384       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 20, 40, 96)           0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 20, 40, 96)           0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 20, 40, 576)          55296     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 20, 40, 576)          2304      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 20, 40, 576)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv (DepthwiseC  (None, 20, 40, 576)          5184      ['block4c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4c_bn (BatchNormaliza  (None, 20, 40, 576)          2304      ['block4c_dwconv[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 20, 40, 576)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 576)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 576)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 24)             13848     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 576)            14400     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 20, 40, 576)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 20, 40, 96)           55296     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 20, 40, 96)           384       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 20, 40, 96)           0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 20, 40, 96)           0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 20, 40, 576)          55296     ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 20, 40, 576)          2304      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 20, 40, 576)          0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv (DepthwiseC  (None, 20, 40, 576)          5184      ['block4d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4d_bn (BatchNormaliza  (None, 20, 40, 576)          2304      ['block4d_dwconv[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 20, 40, 576)          0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 576)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
#
#  block4d_se_reshape (Reshap  (None, 1, 1, 576)            0         ['block4d_se_squeeze[0][0]']
#  e)
#
#  block4d_se_reduce (Conv2D)  (None, 1, 1, 24)             13848     ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)  (None, 1, 1, 576)            14400     ['block4d_se_reduce[0][0]']
#
# ...
#
#  block6e_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multipl  (None, 10, 20, 1392)         0         ['block6e_activation[0][0]',
#  y)                                                                  'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv  (None, 10, 20, 232)          322944    ['block6e_se_excite[0][0]']
#  2D)
#
#  block6e_project_bn (BatchN  (None, 10, 20, 232)          928       ['block6e_project_conv[0][0]']
#  ormalization)
#
#  block6e_drop (Dropout)      (None, 10, 20, 232)          0         ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)           (None, 10, 20, 232)          0         ['block6e_drop[0][0]',
#                                                                      'block6d_add[0][0]']
#
#  block6f_expand_conv (Conv2  (None, 10, 20, 1392)         322944    ['block6e_add[0][0]']
#  D)
#
#  block6f_expand_bn (BatchNo  (None, 10, 20, 1392)         5568      ['block6f_expand_conv[0][0]']
#  rmalization)
#
#  block6f_expand_activation   (None, 10, 20, 1392)         0         ['block6f_expand_bn[0][0]']
#  (Activation)
#
#  block6f_dwconv (DepthwiseC  (None, 10, 20, 1392)         34800     ['block6f_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6f_bn (BatchNormaliza  (None, 10, 20, 1392)         5568      ['block6f_dwconv[0][0]']
#  tion)
#
#  block6f_activation (Activa  (None, 10, 20, 1392)         0         ['block6f_bn[0][0]']
#  tion)
#
#  block6f_se_squeeze (Global  (None, 1392)                 0         ['block6f_activation[0][0]']
#  AveragePooling2D)
#
#  block6f_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block6f_se_squeeze[0][0]']
#  e)
#
#  block6f_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block6f_se_reshape[0][0]']
#
#  block6f_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block6f_se_reduce[0][0]']
#
#  block6f_se_excite (Multipl  (None, 10, 20, 1392)         0         ['block6f_activation[0][0]',
#  y)                                                                  'block6f_se_expand[0][0]']
#
#  block6f_project_conv (Conv  (None, 10, 20, 232)          322944    ['block6f_se_excite[0][0]']
#  2D)
#
#  block6f_project_bn (BatchN  (None, 10, 20, 232)          928       ['block6f_project_conv[0][0]']
#  ormalization)
#
#  block6f_drop (Dropout)      (None, 10, 20, 232)          0         ['block6f_project_bn[0][0]']
#
#  block6f_add (Add)           (None, 10, 20, 232)          0         ['block6f_drop[0][0]',
#                                                                      'block6e_add[0][0]']
#
#  block7a_expand_conv (Conv2  (None, 10, 20, 1392)         322944    ['block6f_add[0][0]']
#  D)
#
#  block7a_expand_bn (BatchNo  (None, 10, 20, 1392)         5568      ['block7a_expand_conv[0][0]']
#  rmalization)
#
#  block7a_expand_activation   (None, 10, 20, 1392)         0         ['block7a_expand_bn[0][0]']
#  (Activation)
#
#  block7a_dwconv (DepthwiseC  (None, 10, 20, 1392)         12528     ['block7a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7a_bn (BatchNormaliza  (None, 10, 20, 1392)         5568      ['block7a_dwconv[0][0]']
#  tion)
#
#  block7a_activation (Activa  (None, 10, 20, 1392)         0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 1392)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 10, 20, 1392)         0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 10, 20, 384)          534528    ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 10, 20, 384)          1536      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, 10, 20, 2304)         884736    ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, 10, 20, 2304)         9216      ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, 10, 20, 2304)         0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, 10, 20, 2304)         20736     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, 10, 20, 2304)         9216      ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, 10, 20, 2304)         0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 2304)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 2304)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 96)             221280    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 2304)           223488    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 10, 20, 2304)         0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 10, 20, 384)          884736    ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 10, 20, 384)          1536      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (Dropout)      (None, 10, 20, 384)          0         ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)           (None, 10, 20, 384)          0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)           (None, 10, 20, 1536)         589824    ['block7b_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 10, 20, 1536)         6144      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 10, 20, 1536)         0         ['top_bn[0][0]']
#  )
#
#  max_pool (GlobalMaxPooling  (None, 1536)                 0         ['top_activation[0][0]']
#  2D)
#
#  batch_normalization (Batch  (None, 1536)                 6144      ['max_pool[0][0]']
#  Normalization)
#
#  dense (Dense)               (None, 256)                  393472    ['batch_normalization[0][0]']
#
#  dropout (Dropout)           (None, 256)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 7)                    1799      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 11184950 (42.67 MB)
# Trainable params: 11094575 (42.32 MB)
# Non-trainable params: 90375 (353.03 KB)
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
# To check
model.layers[-1].get_weights()[0]
# Out:
# array([[ 0.05559245, -0.18024282,  0.12250493, ..., -0.0295473 ,
#         -0.17020807, -0.15949364],
#        [-0.12429732, -0.23267792, -0.21331936, ...,  0.23716791,
#          0.23557101, -0.042546  ],
#        [ 0.05453651, -0.10753678,  0.13634595, ...,  0.07818402,
#         -0.02538554,  0.02428198],
#        ...,
#        [-0.1847724 , -0.11073647,  0.55943775, ...,  0.05239721,
#         -0.440774  , -0.46829966],
#        [-0.23853803,  0.51700175, -0.27631506, ..., -0.24088919,
#         -0.31163523, -0.02179029],
#        [-0.332065  , -0.34693554, -0.32986775, ..., -0.3523678 ,
#         -0.49162748,  0.6808193 ]], dtype=float32)

# %% [markdown]
# ## Prediction

# %%
def predictor(test_gen):
    y_pred= []
    error_list=[]
    error_pred_list = []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)
    for i, p in enumerate(preds):
        pred_index=np.argmax(p)
        true_index=test_gen.labels[i]  # labels are integer values
        if pred_index != true_index: # a misclassification has occurred
            errors=errors + 1
            file=test_gen.filenames[i]
            error_list.append(file)
            error_class=classes[pred_index]
            error_pred_list.append(error_class)
        y_pred.append(pred_index)

    acc=( 1-errors/tests) * 100
    msg=f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}'
    print_in_color(msg, (0,255,255), (100,100,100)) # cyan foreground
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    f1score=f1_score(ytrue, ypred, average='weighted')* 100
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4, output_dict=True) # create classification report
    return errors, tests, error_list, error_pred_list, f1score, y_pred, y_true, clr

# %%
# Original dataset
o_errors, o_tests, o_error_list, o_error_pred_list, o_f1score, o_y_pred, o_y_true, o_clr = predictor(original_test_gen)
# Out:
# 7/7 [==============================] - 14s 2s/step
# there were 60 errors in 259 tests for an accuracy of  76.83

# %%
o_clr
# Out:
# {'0': {'precision': 0.9459459459459459,
#   'recall': 0.7,
#   'f1-score': 0.8045977011494254,
#   'support': 150.0},
#  '1': {'precision': 0.5138888888888888,
#   'recall': 0.8409090909090909,
#   'f1-score': 0.6379310344827587,
#   'support': 44.0},
#  '2': {'precision': 0.76,
#   'recall': 0.8837209302325582,
#   'f1-score': 0.8172043010752689,
#   'support': 43.0},
#  '3': {'precision': 0.8,
#   'recall': 0.8,
#   'f1-score': 0.8000000000000002,
#   'support': 15.0},
#  '4': {'precision': 0.6,
#   'recall': 1.0,
#   'f1-score': 0.7499999999999999,
#   'support': 3.0},
#  '5': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 2.0},
#  '6': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2.0},
#  'accuracy': 0.7683397683397684,
#  'macro avg': {'precision': 0.7314049764049765,
#   'recall': 0.8892328601630927,
#   'f1-score': 0.7823428147677314,
#   'support': 259.0},
#  'weighted avg': {'precision': 0.8261892007837955,
#   'recall': 0.7683397683397684,
#   'f1-score': 0.77792177208195,
#   'support': 259.0}}

# %%
# Generated colored dataset
errors, tests, error_list, error_pred_list, f1score, y_pred, y_true, clr = predictor(test_gen)
# Out:
# 350/350 [==============================] - 1148s 3s/step
# there were 12958 errors in 25900 tests for an accuracy of  49.97

# %%
original_test_df["predictions"] = o_y_pred

# %%
test_df["predictions"] = y_pred

# %%
original_test_df.to_csv(root_path + "ham_test_results/df_test_original.csv")
test_df.to_csv(root_path + "ham_test_results/df_test_ita.csv")
